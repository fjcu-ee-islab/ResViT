# %%
import pandas as pd
import os
import cv2

# %%
df = pd.read_csv("./pick/severe.csv")
#df1 = pd.read_csv("retrain/moderate.csv")

# %%
i=0
j=0
a=0
mid=0
num=6 #要挑的張數(左右各幾)
print(df.values[i,0])
#print(df1.values[j,0])
#os.mkdir('retrain')
os.mkdir('pick/severe'+str(num))
#os.mkdir('retrain/raw/moderate'+str(num))
path = 'pick/severe/'
#path0 = 'retrain/rawmoderate/'
# Out:
# 003034225H

# %%
print('num='+str(num))
#range裡的次數要填眼睛的數量
for i in range(33) :
    if str(df.values[i,1]) == 'OD':
        path1=(path+df.values[i,0]+'/OD/')
    elif str(df.values[i,1]) == 'OS':
        path1=(path+df.values[i,0]+'/OS/')
    dirlist=os.listdir(path1)
    dirlist.sort(key=lambda x:int(x[-8:-4]))
    #print(dirlist[1][-8:-4])
    
    if num==12:
        for n in range(24):
            img0=cv2.imread(path1+dirlist[n])
            print(path)
            print(path1)
            print(dirlist[n])
            cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
            a=a+1

    if num==0:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1     

    if num==1:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1

    if num==2:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1

    if num==3:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1

    if num==4:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1

    if num==5:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
    if num==6:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('pick/severe'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
    if num==7:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path1+dirlist[nnext])
                img14=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img13)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img14)
                a=a+1
    if num==8:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path1+dirlist[nnext])
                img14=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img13)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path1+dirlist[nnext])
                img16=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img15)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img16)
                a=a+1
    if num==9:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path1+dirlist[nnext])
                img14=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img13)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path1+dirlist[nnext])
                img16=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img15)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path1+dirlist[nnext])
                img18=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img17)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img18)
                a=a+1
    if num==10:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path1+dirlist[nnext])
                img14=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img13)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path1+dirlist[nnext])
                img16=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img15)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path1+dirlist[nnext])
                img18=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img17)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img18)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img19=cv2.imread(path1+dirlist[nnext])
                img20=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img19)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img20)
                a=a+1
    if num==11:
        for n in range(24):
            mid=df.values[i,2]
            if int(dirlist[n][-8:-4])==mid:
                img0=cv2.imread(path1+dirlist[n])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path1+dirlist[nnext])
                img2=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img1)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path1+dirlist[nnext])
                img4=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img3)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path1+dirlist[nnext])
                img6=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img5)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path1+dirlist[nnext])
                img8=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img7)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path1+dirlist[nnext])
                img10=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img9)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path1+dirlist[nnext])
                img12=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img11)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path1+dirlist[nnext])
                img14=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img13)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path1+dirlist[nnext])
                img16=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img15)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path1+dirlist[nnext])
                img18=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img17)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img18)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img19=cv2.imread(path1+dirlist[nnext])
                img20=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img19)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img20)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img21=cv2.imread(path1+dirlist[nnext])
                img22=cv2.imread(path1+dirlist[nlast])
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img21)
                a=a+1
                cv2.imwrite('retrain/raw/normal'+str(num)+'/0'+str(a).zfill(4)+'.png',img22)
                a=a+1
# Out:
# num=6

# %%
print('num='+str(num))
a=0
n=0
for j in range(35) :
    if str(df1.values[j,1]) == 'OD':
        path2=(path0+df1.values[j,0]+'/OD/')
    elif str(df1.values[j,1]) == 'OS':
        path2=(path0+df1.values[j,0]+'/OS/')
    dirlist1=os.listdir(path2)
    dirlist1.sort(key=lambda x:int(x[-8:-4]))
    #print(dirlist[1][-8:-4])
    if num==12:
        for n in range(24):
            img0=cv2.imread(path2+dirlist1[n])
            print(a)
            cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
            a=a+1
            
    if num==0:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1     

    if num==1:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1

    if num==2:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1

    if num==3:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1

    if num==4:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1

    if num==5:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
    if num==6:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/moderate'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
    if num==7:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path2+dirlist1[nnext])
                img14=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img13)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img14)
                a=a+1
    if num==8:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path2+dirlist1[nnext])
                img14=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img13)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path2+dirlist1[nnext])
                img16=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img15)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img16)
                a=a+1
    if num==9:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path2+dirlist1[nnext])
                img14=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img13)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path2+dirlist1[nnext])
                img16=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img15)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path2+dirlist1[nnext])
                img18=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img17)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img18)
                a=a+1
    if num==10:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path2+dirlist1[nnext])
                img14=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img13)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path2+dirlist1[nnext])
                img16=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img15)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path2+dirlist1[nnext])
                img18=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img17)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img18)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img19=cv2.imread(path2+dirlist1[nnext])
                img20=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img19)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img20)
                a=a+1
    if num==11:
        for n in range(24):
            mid=df1.values[j,2]
            if int(dirlist1[n][-8:-4])==mid:
                img0=cv2.imread(path2+dirlist1[n])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img0)
                a=a+1
                nnext=n+1
                if nnext>23:
                    nnext=0
                nlast=n-1
                if nlast<0:
                    nlast=23
                img1=cv2.imread(path2+dirlist1[nnext])
                img2=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img1)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img2)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img3=cv2.imread(path2+dirlist1[nnext])
                img4=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img3)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img4)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img5=cv2.imread(path2+dirlist1[nnext])
                img6=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img5)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img6)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img7=cv2.imread(path2+dirlist1[nnext])
                img8=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img7)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img8)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img9=cv2.imread(path2+dirlist1[nnext])
                img10=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img9)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img10)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img11=cv2.imread(path2+dirlist1[nnext])
                img12=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img11)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img12)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img13=cv2.imread(path2+dirlist1[nnext])
                img14=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img13)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img14)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img15=cv2.imread(path2+dirlist1[nnext])
                img16=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img15)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img16)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img17=cv2.imread(path2+dirlist1[nnext])
                img18=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img17)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img18)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img19=cv2.imread(path2+dirlist1[nnext])
                img20=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img19)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img20)
                a=a+1
                nnext=nnext+1
                if nnext>23:
                    nnext=0
                nlast=nlast-1
                if nlast<0:
                    nlast=23
                img21=cv2.imread(path2+dirlist1[nnext])
                img22=cv2.imread(path2+dirlist1[nlast])
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img21)
                a=a+1
                cv2.imwrite('retrain/raw/severe'+str(num)+'/0'+str(a).zfill(4)+'.jpg',img22)
                a=a+1
# Out:
# num=6
